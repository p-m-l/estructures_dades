# %%
#Exercicis
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv('preu lloguer per trimestre i barri.csv')
df = pd.DataFrame(df)

c1 = df['Trimestre']
c2 = df['Nom_Districte']
c3 = df['Preu']

# Create bars
plt.bar(c2, c3)

# Create names on the x-axis
plt.xticks(c2, c2)
plt.tight_layout()
# Show graphic
plt.show()

plt.savefig('bars.png')

# %%
#Exercicis

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('preu lloguer per trimestre i barri.csv')
df = pd.DataFrame(df)

c1 = df['Trimestre']
c2 = df['Nom_Districte']
c3 = df['Preu']

plt.scatter(x=c1,y=c2,s=c3/3,cmap="jet",alpha=0.2,)

plt.colorbar(label="Preu", orientation="horizontal")

plt.savefig('scatter.png')
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_7668\103086337.py:17: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(label="Preu", orientation="horizontal")
